# %% [markdown]
# # Intro to JupyterLab
#
# Here we are, starting with using yet another tool: JupyterLab
#
# > Note: If you are using an IDE (integrated development environment) like VSCode, some keyboard short cuts may differ.

# %% [markdown]
# ## Objectives
#
# At the end of this notebook you will be able to:
#
# - Run cells in JupyterLab and change them to markdown or code cell
#
# - Differentiate between Command and Edit Mode and to change between them
#
# - Run UNIX commands in JupyterLab
#
# - Receiving help from docstrings

# %% [markdown]
# ## Running Cells
#
# **Welcome to programming!**
#
# Juptyer Notebooks (historically called IPython Notebooks) will be the primary tool when conducting data science. The first thing to understand with these notebooks is that each **cell block** [of code] can be run be pressing: **Shift+Enter** or **Ctrl+Enter**. Or, if your keyboard has a German layout: **Strg+Enter**.
#
# Try running the below code block:

# %%
print('This is the code being run. Here is the output of the code block.')
# Out:
# This is the code being run. Here is the output of the code block.

# %% [markdown]
# The output of the code will be found directly beneath the cell block.

# %% [markdown]
# ## Cell Types
#
# You might have started to notice already that the code blocks have little notes that say **[ ]:** before you run them, and then are filled with a number after you run them.
#
# This is important because it tells you what order cell blocks were run, which sometimes affects how a program runs.
#
# You may also notice that other cell blocks, such as this one, do not have the **[ ]:** label as with the code blocks.
#
# This is because this cell block is formatted as **Markdown** rather than code. The details of Markdown are not important here but just know you can use markdown cell blocks to display text and images. They are really useful for embedding notes and explanations in your Jupyter Notebook.
#
# You can see and change what format a cell is by using the menu at the top.

# %% [markdown]
# <img src="images/jupyter_cell_type.png" width="900">

# %% [markdown]
# Or it may look like this if you are using VSCode.
#
# <img src="images/jupyter_cell_type_2.png" width="900">

# %% [markdown]
# You can **Edit** a markdown by double **clicking** on it. Try that now (double click **HERE**) and you will see the cell type in the bottom right corner.

# %% [markdown]
# ## Command Versus Edit Mode

# %% [markdown]
# We distinguish between two modes in JupyterLab:
#
# 1. The edit mode where you can write code or notes
# 2. Command mode where you can delete or copy cells
#
# To switch from edit mode to command mode, you can press **Esc**, (you cannot write in the cell now) and press **Enter** to enter edit mode again.
#
# ### Edit Mode
#
# Edit mode is the standard mode for editing cells, whether it's writing code or notes.
#
# To enter edit mode from command mode simply hit **Enter**, or double click on a cell.
#
# ### Command Mode
# In command mode, you can delete cells, add cells, copy cells, paste cells, change cell types and more.
#
# You can also do these tasks in a more time consuming way by using the various headers in the menu bar at the top.
#
# <img src="images/jupyter_commandS.png" width="800">

# %% [markdown]
# If you want to learn more about the functionalities of JupyterLab, here is the detailed [Documentation](https://jupyterlab.readthedocs.io/en/stable/user/notebook.html).

# %% [markdown]
# ## Running Bash Commands
#
# You can also run Bash commands, just as we did before from the terminal, directly within Jupyter Notebooks!
#
# **Note**: Bash commands cannot be mixed with Python and must be in their own cell block.
#
# Try it out!

# %%
pwd
# Out:
# '/Users/spiced/Desktop/ds-python-basics'

# %%
ls
# Out:
# Basics/                      images/
# Coding_best_practices.ipynb  Intro_to_Jupyter_Lab.ipynb
# Data_Structures_in_Python/   README.md
# Functions/                   requirements.txt

# %% [markdown]
# ## Autocomplete and Getting Help
#
#
# Like in Colab there is the autocomplete function.
#
# When you start typing code, you can see a subset of the available commands **when you press tab**.
#
# You can use "Enter" to auto-complete the first command, otherwise you can use the arrow keys to scroll through all the commands and press "Enter" to complete the command.
#
#  <img src="images/jupyter_autocomplete.png" width="800">

# %% [markdown]
# ## Calling Docstrings
#
# Of course, docstrings are working here too
# You can do this by writing **?** after the method and executing the cell:
#
#  <img src="images/jupyter_docstring_2.png" width="800">
#
#
# Or you use **Shift+Tab** to get help automatically without executing the cell.
#
#  <img src="images/jupyter_docstring.png" width="800">

# %%
# Try it out!

# %% [markdown]
# ## Stop Execution
#
# Long running or infinitely looping python processes can be interrupted.
#
# Run the following cell either:
#
# 1. Select **Kernel -> Interrupt kernel** to stop execution.
# 2. Select the **Interrupt** option in the top menu
# 2. Click the **Stop** (square) symbol in the top left corner of the cell.
#
# Try it out:

# %%
import time
print("Sleeping")
time.sleep(30) # sleep for a while; interrupt me!
print("Done Sleeping")
# Out:
# Sleeping
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 import time
#       2 print("Sleeping")
# ----> 3 time.sleep(30) # sleep for a while; interrupt me!
#       4 print("Done Sleeping")
#
# KeyboardInterrupt:

# %% [markdown]
# Sometimes Notebooks can get a bit chaotic and you might encounter that in your first project.
#
# In order for you and others to go through your notebook smoothly, it is important that the cells are executed in the correct order (from top to bottom). To check if this is possible, we recommend that you run **Kernel --> Restart Kernel and Run All Cells...** every now and then.

# %% [markdown]
# ## Check your understanding!
#
#
# Try to do all these tasks with shortcuts. Of course, feel free to test other shortcuts to get more familiar with them.
#
# 1. Create a new cell below
#
# 2. Change the celltype to "markdown"
#
# 3. Enter the cell and write "print('Congratulations! You are now familiar with JupyterLab!')"
#
# 4. Exit the edit mode and change celltype to "Code"
#
# 5. Copy the cell and paste it below
#
# 6. Delete the last cell again
#
# 7. Run the cell --> you're done!
