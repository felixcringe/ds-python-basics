# %% [markdown]
# # 4. Challenge

# %% [markdown]
# ## Instructions

# %% [markdown]
# For this assignment you'll be working working through more problems by building functions from scratch.
#
# For each problem, you should build a function as your solution. You will build each function in it's own cell and then call it with some arguments in the next cell right after you define it.

# %% [markdown]
# For example, pretend the following is the solution to one of the problems, written in a function first and then called (for testing purposes) below:

# %%
from pygments.lexers import j


def my_func(param1, param2, param3):
    # Code to solve the problem goes here
    return result

# %%
print(my_func(param11, param21, param31))
print(my_func(param12, param22, param32))
print(my_func(param13, param23, param33))
print(my_func(param14, param24, param34))
print(my_func(param15, param25, param35))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(my_func(param11, param21, param31))
#       2 print(my_func(param12, param22, param32))
#       3 print(my_func(param13, param23, param33))
#       4 print(my_func(param14, param24, param34))
#
# NameError: name 'param11' is not defined

# %% [markdown]
# Note above that `my_func` is called five times after it's definition. These tests should check that `my_func` works correctly with different sets of arguments.
#
# You should aim to test your functions at least 5 times after you write them. It's good to try and think of tests that your function might not solve correctly (we call these **edge cases**). Not only does thinking like this help you solve the problem, but it also gives you more confidence in your solution.

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Part 1 - Basic Practice

# %% [markdown]
# For the first part of the assignment, we're going to get some practice taking something we've already written and translating it to a function.
#
# In continuation of prior assignments,
#
# 1. Write a function that computes the factorial for an inputted number.
#
# 2. Write a function that determines whether or not an inputted number is prime, and then prints 'The number you inputted is a prime/ not a prime number.' depending on what your script finds (note that this means putting a `print` in front of the function when testing it will be redundant for this case).

# %%
# Answer Here
def factorial(n):
    if n < 0:
        return "Error, do not pass negative number"
    elif n == 0:
        return 1
    else:
        return n * factorial(n-1)

# %%
factorial(5)
factorial(10)
factorial(0)
factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
# Prime number?
def isprime(n: int) -> bool:
    if n < 2:
        return False
    else:
        for i in range(2, n+1):
            if n % i == 0 and i != n:
                return False
            elif n % i > 0 and i != n:
                continue
            elif n % i == 0 and n == i:
                return True
        return False

# %%
#isprime(5)
#isprime(100)
#isprime(44)
print("The number you inputted is a prime number.") if isprime(int(input())) is True else print("The number you inputted is a not prime number.")
# Out:
# The number you inputted is a prime number.

# %% [markdown]
# ### Part 2 - Advanced Practice

# %% [markdown]
# Now we're going to push your problem solving and programming skills even further by coding up functions to solve new problems.
#
# For each of the problems below, We would suggest coding it up in a similar way to how you did the other two (building the function, and then calling it some number of times (5) to test it out after that).
#
# 1. Write a function that counts the number of words in an inputted string, where we consider words to be separated by spaces.
#
# 2. Write a function that counts the number of words in an inputted string, where we consider words to be separated by a specified delimiter
#
#     - so your function should accept two arguments, one for the string and one for the delimiter, and a space is defined as the default delimiter.
#
# 3. Write a function that takes in a string and returns a list that holds the length of each word in the phrase, separated by an inputted delimiter
#
#     - you're function should accept two arguments again.
#
#     - Make a space the default delimiter like you did in `2`. For example, if the arguments to your function were `This is a test string` (and nothing else), your function should return `[4, 2, 1, 4, 6]`.
#
#     - Don't worry about removing punctuation, you can include it in the word length - e.g. "this." has five letters, if we count the period.
#
# 4. Write a function that returns all the prime numbers up to an inputted number.
#
#     - **Hint**: It might be helpful to use/modify the prime function you wrote earlier.
#
# 5. Write a function that takes in a list of numbers, as well as an additional number (i.e. two arguments), and returns a list of `yes` or `no` depending on whether each number in the list is divisible by the second number.
#
#     - For example, if you input `[10, 25, 36, 12, 20]` as the list of numbers, and `5` as the additional number, your function should return `['yes', 'yes', 'no', 'no', 'yes']`.
#
# 6. Write a function that takes in a list of strings, as well as an inputted letter (which looks like a string with a single character), and returns a list of only those strings from the input list that end with that letter.
#
#     - For example, if I input `['I', 'am', 'in', 'love', 'with', 'Python']` as the list of strings, and `n` as the inputted letter, your function should return `['in', 'Python']`.
#
# 7. Write a function that takes in a list of strings, as well as an inputted substring (i.e. another string), and returns a list of the indices of the strings that contain that inputted substring.
#
#     - For example, if I input `['This', 'is, 'an' , 'example']` as the list of strings, and `is` as the substring, your function should return `[0, 1]`.

# %%
# 1. and 2.
def count_words(sentence: str, delimiter=' ') -> int:
    words = sentence.split(delimiter)
    return len(words)

def word_length(sentence: str, delimiter=' ') -> list:
    words = sentence.split(delimiter)
    return [len(word) for word in words]

def primenumbers(n: int) -> list:
    return [i for i in range(2, n+1) if isprime(i)]

def divisible(numbers: list, n: int) -> list:
    return ['yes' if i % n == 0 else 'no' for i in numbers]

def ends_with_letter(words: list, letter: str) -> list:
    return [word for word in words if word[-1] == letter]

def exists_substring(words: list, substring: str) -> list:
    return [word for word in words if substring in word]

# %%
count_words("Dies ist ein Test")
count_words("a b c d e f g h")
count_words("dies, ist , ein test", delimiter=",")

word_length("haha das ist super gut")

primenumbers(50)

divisible([10, 25, 36, 12, 20], 5)

ends_with_letter(['I', 'am', 'in', 'love', 'with', 'Python'], 'n')

exists_substring(['This', 'is', 'an', 'example'], 'is')
# Out:
# ['This', 'is']

# %% [markdown]
# ### Extra Challenge
#
# 1. Let's build a calculator for figuring out how much you owe in taxes (and by calculator, we mean a function).
#
# Write a function that takes in a list of tuples, where each tuple contains two values as well as an income to compute the taxes on (so your function should accept two arguments).
#
# For the tuple list, the first value of a tuple will be an income upper bound, and the second will be a tax rate for all income up to the given income bound.
#
# You need to build a calculator that will calculate the tax for all income up to each income bound (if it goes up that high) for the given tax rate. You can assume that the list of tuples will be sorted by the income bound (e.g. the first value in the tuple), such that the lowest income bound will be first, and the highest last (see below for an example).
#
# - As an example, let's say my tax info is `[(50000, 0.08), (100000, 0.10), (150000, 0.15)]`. This means that the first 50k of income is taxed at 8% (we wish!), the second 50k at 10% (yeah right!), and the rest at 15% (note here: that any income which comes after the 150k is taxed at 15%. Therefore, giving a highest upper bound is misleading because everything above 100k will be taxed at 15%).
#
# - So, if the inputted income was 170k, then my taxes would be:
#     - 50 * 0.08 + 50 * 0.10 + 70 * 0.15 = 19.5k.
#
# - And if the inputted income was 70k, then my taxes would be:
#     - 50 * 0.08 + 20 * 0.10 = 6k.
#
#  You should write your function to be generalized to accept any kind of list of tuples and any inputted income (so it'll accept two arguments).
#
# 2. Now modify your solution to accept a list of tuples that is not sorted by the income bound.
#
# - **Hint**: Trying using the `sorted` function and working with the `key` argument (a [lambda](https://www.educative.io/blog/python-lambda-functions-tutorial) function will probably be helpful here).

# %%
def taxes(taxes: list, income: float) -> float:
    rest = income
    final_tax = 0
    taxes.sort(key=lambda x: x[0])
    for item in taxes:
        final_tax += item[0]
    for i, tax in enumerate(taxes):
        if i == 0:
            final_tax += tax[0] * tax[1]
            rest -= tax[0]
        if i > 0:
            if rest > (taxes[i][0]-taxes[i-1][0]) and i != len(taxes)-1:
                final_tax += (taxes[i][0]-taxes[i-1][0]) * tax[1]
                rest -= (taxes[i][0]-taxes[i-1][0])
            else:
                final_tax += rest * tax[1]
                rest = 0
    return final_tax

# %%
taxes([(50000, 0.08), (100000, 0.1), (150000, 0.15)], 70000)
# Out:
# [(50000, 0.15), (100000, 0.1), (150000, 0.08)]
# 309500.0
